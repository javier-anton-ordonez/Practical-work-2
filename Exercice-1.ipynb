# %% [markdown]
# # Exercice 1

# %% [markdown]
# # Data Clining + EDA

# %%
# %matplotlib inline
import numpy as np
# !pip uninstall pandas-profiling
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
import pandas as pd
import numpy as np
import zipfile
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import IPython
from sklearn.preprocessing import MinMaxScaler

from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy<1.17,>=1.8 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.11.9)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.9.4)
# Requirement already satisfied: dacite<2,>=1.9 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from ydata-profiling==0.0.dev0) (0.61.0)
# Requirement already satisfied: PyWavelets in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling==0.0.dev0) (1.9.0)
# Requirement already satisfied: pillow in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling==0.0.dev0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling==0.0.dev0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from numba<0.63,>=0.60->ydata-profiling==0.0.dev0) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling==0.0.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling==0.0.dev0) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from phik<0.13,>=0.12.5->ydata-profiling==0.0.dev0) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling==0.0.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling==0.0.dev0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling==0.0.dev0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling==0.0.dev0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling==0.0.dev0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling==0.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling==0.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling==0.0.dev0) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (3.5)
# Requirement already satisfied: puremagic in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==0.0.dev0) (1.30)
# Requirement already satisfied: six>=1.5 in /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling==0.0.dev0) (1.17.0)

# %%
data_file_path = 'air_quality.csv'
full_data = pd.read_csv(data_file_path, sep=';')

# %%
full_data
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
print(f"Nulls in Unnamed: 15: {full_data['Unnamed: 15'].isnull().sum()/len(full_data)*100}%")
print(f"Nulls in Unnamed: 16: {full_data['Unnamed: 16'].isnull().sum()/len(full_data)*100}%")
# Out:
# Nulls in Unnamed: 15: 100.0%
# Nulls in Unnamed: 16: 100.0%

# %%
full_data = full_data.drop(columns=['Unnamed: 15', 'Unnamed: 16'])

# %%
mask = full_data.isna().all(axis=1)
all_nan_rows = full_data[mask]
all_nan_rows
# Out:
#      Date Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9357  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9358  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9359  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9360  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9361  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# ...   ...  ...    ...          ...       ...      ...            ...      ...
# 9466  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9467  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9468  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9469  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9470  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    T   RH   AH
# 9357           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9358           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9359           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9360           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9361           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# ...            ...      ...           ...          ...  ...  ...  ...
# 9466           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9467           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9468           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9469           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9470           NaN      NaN           NaN          NaN  NaN  NaN  NaN
#
# [114 rows x 15 columns]

# %%
full_data = full_data[~mask]

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
# dtypes: float64(8), object(7)
# memory usage: 1.1+ MB

# %%
profile = ProfileReport(
    full_data,
    title = "Simple Linear Regression - Precleaning Report",
    html  = {'style': {'full_width': True}},
    sort  = None)
profile.to_file(output_file='Precleaning.html')
# Out:
# 100%|██████████| 15/15 [00:01<00:00, 14.15it/s]1<00:00,  6.81it/s, Describe variable: AH]
# Summarize dataset: 100%|██████████| 88/88 [00:10<00:00,  8.13it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:08<00:00,  8.15s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 38.15it/s]

# %%
for col in full_data.select_dtypes(include='number'):
    if col == "Date" or col == "Time":
        continue
    print(f"Column: {col}")
    negative_values = full_data[full_data[col] < 0]
# Out:
# Column: PT08.S1(CO)
# Column: NMHC(GT)
# Column: PT08.S2(NMHC)
# Column: NOx(GT)
# Column: PT08.S3(NOx)
# Column: NO2(GT)
# Column: PT08.S4(NO2)
# Column: PT08.S5(O3)

# %%
negative_values
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 524   01/04/2004  14.00.00    1,7       -200.0     222.0   -200,0
# 525   01/04/2004  15.00.00    1,9       -200.0     197.0   -200,0
# 526   01/04/2004  16.00.00    2,3       -200.0     319.0   -200,0
# 701   08/04/2004  23.00.00      2       -200.0     137.0   -200,0
# 702   09/04/2004  00.00.00    2,4       -200.0     189.0   -200,0
# ...          ...       ...    ...          ...       ...      ...
# 8111  11/02/2005  17.00.00    6,6       -200.0    -200.0   -200,0
# 8112  11/02/2005  18.00.00    6,5       -200.0    -200.0   -200,0
# 8113  11/02/2005  19.00.00    7,1       -200.0    -200.0   -200,0
# 8114  11/02/2005  20.00.00    4,9       -200.0    -200.0   -200,0
# 8777  11/03/2005  11.00.00    3,0       -200.0    -200.0   -200,0
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 524          -200.0     99.0        -200.0     72.0        -200.0
# 525          -200.0    108.0        -200.0     81.0        -200.0
# 526          -200.0    131.0        -200.0     93.0        -200.0
# 701          -200.0    129.0        -200.0    106.0        -200.0
# 702          -200.0    154.0        -200.0    109.0        -200.0
# ...             ...      ...           ...      ...           ...
# 8111         -200.0   1227.0        -200.0    326.0        -200.0
# 8112         -200.0   1061.0        -200.0    284.0        -200.0
# 8113         -200.0   1075.0        -200.0    289.0        -200.0
# 8114         -200.0    641.0        -200.0    215.0        -200.0
# 8777         -200.0    812.0        -200.0    235.0        -200.0
#
#       PT08.S5(O3)     T    RH    AH
# 524        -200.0  -200  -200  -200
# 525        -200.0  -200  -200  -200
# 526        -200.0  -200  -200  -200
# 701        -200.0  -200  -200  -200
# 702        -200.0  -200  -200  -200
# ...           ...   ...   ...   ...
# 8111       -200.0  -200  -200  -200
# 8112       -200.0  -200  -200  -200
# 8113       -200.0  -200  -200  -200
# 8114       -200.0  -200  -200  -200
# 8777       -200.0  -200  -200  -200
#
# [366 rows x 15 columns]

# %%
full_data = full_data.replace(-200.0, pd.NA)
full_data = full_data.replace(-200, pd.NA)
full_data = full_data.replace("-200", pd.NA)

# %%
full_data
# Out:
#             Date      Time CO(GT) PT08.S1(CO) NMHC(GT) C6H6(GT) PT08.S2(NMHC)  \
# 0     10/03/2004  18.00.00    2,6      1360.0    150.0     11,9        1046.0
# 1     10/03/2004  19.00.00      2      1292.0    112.0      9,4         955.0
# 2     10/03/2004  20.00.00    2,2      1402.0     88.0      9,0         939.0
# 3     10/03/2004  21.00.00    2,2      1376.0     80.0      9,2         948.0
# 4     10/03/2004  22.00.00    1,6      1272.0     51.0      6,5         836.0
# ...          ...       ...    ...         ...      ...      ...           ...
# 9352  04/04/2005  10.00.00    3,1      1314.0     <NA>     13,5        1101.0
# 9353  04/04/2005  11.00.00    2,4      1163.0     <NA>     11,4        1027.0
# 9354  04/04/2005  12.00.00    2,4      1142.0     <NA>     12,4        1063.0
# 9355  04/04/2005  13.00.00    2,1      1003.0     <NA>      9,5         961.0
# 9356  04/04/2005  14.00.00    2,2      1071.0     <NA>     11,9        1047.0
#
#      NOx(GT) PT08.S3(NOx) NO2(GT) PT08.S4(NO2) PT08.S5(O3)     T    RH      AH
# 0      166.0       1056.0   113.0       1692.0      1268.0  13,6  48,9  0,7578
# 1      103.0       1174.0    92.0       1559.0       972.0  13,3  47,7  0,7255
# 2      131.0       1140.0   114.0       1555.0      1074.0  11,9  54,0  0,7502
# 3      172.0       1092.0   122.0       1584.0      1203.0  11,0  60,0  0,7867
# 4      131.0       1205.0   116.0       1490.0      1110.0  11,2  59,6  0,7888
# ...      ...          ...     ...          ...         ...   ...   ...     ...
# 9352   472.0        539.0   190.0       1374.0      1729.0  21,9  29,3  0,7568
# 9353   353.0        604.0   179.0       1264.0      1269.0  24,3  23,7  0,7119
# 9354   293.0        603.0   175.0       1241.0      1092.0  26,9  18,3  0,6406
# 9355   235.0        702.0   156.0       1041.0       770.0  28,3  13,5  0,5139
# 9356   265.0        654.0   168.0       1129.0       816.0  28,5  13,1  0,5028
#
# [9357 rows x 15 columns]

# %% [markdown]
# ## Missing porcentage of each column

# %%
for col in full_data.columns:
    num_nulls = full_data[col].isnull().sum()
    if num_nulls > 0:
        print(f"Column '{col}'\t has {num_nulls} null values\t ({num_nulls/len(full_data)*100:.2f}%)")
# Out:
# Column 'CO(GT)'	 has 1592 null values	 (17.01%)
# Column 'PT08.S1(CO)'	 has 366 null values	 (3.91%)
# Column 'NMHC(GT)'	 has 8443 null values	 (90.23%)
# Column 'PT08.S2(NMHC)'	 has 366 null values	 (3.91%)
# Column 'NOx(GT)'	 has 1639 null values	 (17.52%)
# Column 'PT08.S3(NOx)'	 has 366 null values	 (3.91%)
# Column 'NO2(GT)'	 has 1642 null values	 (17.55%)
# Column 'PT08.S4(NO2)'	 has 366 null values	 (3.91%)
# Column 'PT08.S5(O3)'	 has 366 null values	 (3.91%)
# Column 'T'	 has 366 null values	 (3.91%)
# Column 'RH'	 has 366 null values	 (3.91%)
# Column 'AH'	 has 366 null values	 (3.91%)

# %%
full_data_cleaned = full_data.drop(columns=['NMHC(GT)'])

# %%
full_data_cleaned
# Out:
#             Date      Time CO(GT) PT08.S1(CO) C6H6(GT) PT08.S2(NMHC) NOx(GT)  \
# 0     10/03/2004  18.00.00    2,6      1360.0     11,9        1046.0   166.0
# 1     10/03/2004  19.00.00      2      1292.0      9,4         955.0   103.0
# 2     10/03/2004  20.00.00    2,2      1402.0      9,0         939.0   131.0
# 3     10/03/2004  21.00.00    2,2      1376.0      9,2         948.0   172.0
# 4     10/03/2004  22.00.00    1,6      1272.0      6,5         836.0   131.0
# ...          ...       ...    ...         ...      ...           ...     ...
# 9352  04/04/2005  10.00.00    3,1      1314.0     13,5        1101.0   472.0
# 9353  04/04/2005  11.00.00    2,4      1163.0     11,4        1027.0   353.0
# 9354  04/04/2005  12.00.00    2,4      1142.0     12,4        1063.0   293.0
# 9355  04/04/2005  13.00.00    2,1      1003.0      9,5         961.0   235.0
# 9356  04/04/2005  14.00.00    2,2      1071.0     11,9        1047.0   265.0
#
#      PT08.S3(NOx) NO2(GT) PT08.S4(NO2) PT08.S5(O3)     T    RH      AH
# 0          1056.0   113.0       1692.0      1268.0  13,6  48,9  0,7578
# 1          1174.0    92.0       1559.0       972.0  13,3  47,7  0,7255
# 2          1140.0   114.0       1555.0      1074.0  11,9  54,0  0,7502
# 3          1092.0   122.0       1584.0      1203.0  11,0  60,0  0,7867
# 4          1205.0   116.0       1490.0      1110.0  11,2  59,6  0,7888
# ...           ...     ...          ...         ...   ...   ...     ...
# 9352        539.0   190.0       1374.0      1729.0  21,9  29,3  0,7568
# 9353        604.0   179.0       1264.0      1269.0  24,3  23,7  0,7119
# 9354        603.0   175.0       1241.0      1092.0  26,9  18,3  0,6406
# 9355        702.0   156.0       1041.0       770.0  28,3  13,5  0,5139
# 9356        654.0   168.0       1129.0       816.0  28,5  13,1  0,5028
#
# [9357 rows x 14 columns]

# %%
for col in full_data_cleaned.columns:
    num_nulls = full_data_cleaned[col].isnull().sum()
    if num_nulls > 0:
        print(f"Column '{col}'\t has {num_nulls} null values\t ({num_nulls/len(full_data_cleaned)*100:.2f}%)")
# Out:
# Column 'CO(GT)'	 has 1592 null values	 (17.01%)
# Column 'PT08.S1(CO)'	 has 366 null values	 (3.91%)
# Column 'PT08.S2(NMHC)'	 has 366 null values	 (3.91%)
# Column 'NOx(GT)'	 has 1639 null values	 (17.52%)
# Column 'PT08.S3(NOx)'	 has 366 null values	 (3.91%)
# Column 'NO2(GT)'	 has 1642 null values	 (17.55%)
# Column 'PT08.S4(NO2)'	 has 366 null values	 (3.91%)
# Column 'PT08.S5(O3)'	 has 366 null values	 (3.91%)
# Column 'T'	 has 366 null values	 (3.91%)
# Column 'RH'	 has 366 null values	 (3.91%)
# Column 'AH'	 has 366 null values	 (3.91%)

# %%
filas_con_nan = full_data_cleaned[full_data_cleaned.isna().any(axis=1)]
filas_con_nan
# Out:
#             Date      Time CO(GT) PT08.S1(CO) C6H6(GT) PT08.S2(NMHC) NOx(GT)  \
# 9     11/03/2004  03.00.00    0,6      1010.0      1,7         561.0    <NA>
# 10    11/03/2004  04.00.00   <NA>      1011.0      1,3         527.0    21.0
# 33    12/03/2004  03.00.00    0,8       889.0      1,9         574.0    <NA>
# 34    12/03/2004  04.00.00   <NA>       831.0      1,1         506.0    21.0
# 39    12/03/2004  09.00.00   <NA>      1545.0     22,1        1353.0    <NA>
# ...          ...       ...    ...         ...      ...           ...     ...
# 8697  08/03/2005  03.00.00    0,8       876.0      1,9         576.0    <NA>
# 8721  09/03/2005  03.00.00    0,8       937.0      2,2         600.0    <NA>
# 8745  10/03/2005  03.00.00    1,1      1014.0      4,4         731.0    <NA>
# 8755  10/03/2005  13.00.00    2,3      1176.0      9,8         969.0    <NA>
# 8777  11/03/2005  11.00.00    3,0        <NA>   -200,0          <NA>   812.0
#
#      PT08.S3(NOx) NO2(GT) PT08.S4(NO2) PT08.S5(O3)     T    RH      AH
# 9          1705.0    <NA>       1235.0       501.0  10,3  60,2  0,7517
# 10         1818.0    34.0       1197.0       445.0  10,1  60,5  0,7465
# 33         1680.0    <NA>       1187.0       512.0   7,0  62,3  0,6261
# 34         1893.0    32.0       1134.0       384.0   6,1  65,9  0,6248
# 39          767.0    <NA>       2058.0      1588.0   9,2  56,2  0,6561
# ...           ...     ...          ...         ...   ...   ...     ...
# 8697       1040.0    <NA>        815.0       900.0   1,0  56,7  0,3803
# 8721        985.0    <NA>        873.0       885.0   4,7  53,1  0,4589
# 8745        784.0    <NA>       1062.0      1038.0   4,6  78,2  0,6684
# 8755        612.0    <NA>       1196.0      1300.0  18,8  26,2  0,5637
# 8777         <NA>   235.0         <NA>        <NA>  <NA>  <NA>    <NA>
#
# [2333 rows x 14 columns]

# %%
filas_con_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2333 entries, 9 to 8777
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           2333 non-null   object
#  1   Time           2333 non-null   object
#  2   CO(GT)         741 non-null    object
#  3   PT08.S1(CO)    1967 non-null   object
#  4   C6H6(GT)       2333 non-null   object
#  5   PT08.S2(NMHC)  1967 non-null   object
#  6   NOx(GT)        694 non-null    object
#  7   PT08.S3(NOx)   1967 non-null   object
#  8   NO2(GT)        691 non-null    object
#  9   PT08.S4(NO2)   1967 non-null   object
#  10  PT08.S5(O3)    1967 non-null   object
#  11  T              1967 non-null   object
#  12  RH             1967 non-null   object
#  13  AH             1967 non-null   object
# dtypes: object(14)
# memory usage: 273.4+ KB

# %%
mask = {
    'ah_missing': full_data_cleaned['AH'].isna() & full_data_cleaned['T'].notna() & full_data_cleaned['RH'].notna(),
    'rh_missing': full_data_cleaned['RH'].isna() & full_data_cleaned['T'].notna() & full_data_cleaned['AH'].notna()
}

print(full_data_cleaned.loc[mask['ah_missing'], 'AH'].sum())
print(full_data_cleaned.loc[mask['rh_missing'], 'RH'].sum())
# Out:
# 0
# 0

# %%
full_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         7765 non-null   object
#  3   PT08.S1(CO)    8991 non-null   object
#  4   C6H6(GT)       9357 non-null   object
#  5   PT08.S2(NMHC)  8991 non-null   object
#  6   NOx(GT)        7718 non-null   object
#  7   PT08.S3(NOx)   8991 non-null   object
#  8   NO2(GT)        7715 non-null   object
#  9   PT08.S4(NO2)   8991 non-null   object
#  10  PT08.S5(O3)    8991 non-null   object
#  11  T              8991 non-null   object
#  12  RH             8991 non-null   object
#  13  AH             8991 non-null   object
# dtypes: object(14)
# memory usage: 1.3+ MB

# %%
for col in full_data_cleaned.columns:
    num_nulls = full_data_cleaned[col].isnull().sum()
    if num_nulls > 0:
        print(f"Column '{col}'\t has {num_nulls} null values\t ({num_nulls/len(full_data_cleaned)*100:.2f}%)")
# Out:
# Column 'CO(GT)'	 has 1592 null values	 (17.01%)
# Column 'PT08.S1(CO)'	 has 366 null values	 (3.91%)
# Column 'PT08.S2(NMHC)'	 has 366 null values	 (3.91%)
# Column 'NOx(GT)'	 has 1639 null values	 (17.52%)
# Column 'PT08.S3(NOx)'	 has 366 null values	 (3.91%)
# Column 'NO2(GT)'	 has 1642 null values	 (17.55%)
# Column 'PT08.S4(NO2)'	 has 366 null values	 (3.91%)
# Column 'PT08.S5(O3)'	 has 366 null values	 (3.91%)
# Column 'T'	 has 366 null values	 (3.91%)
# Column 'RH'	 has 366 null values	 (3.91%)
# Column 'AH'	 has 366 null values	 (3.91%)

# %%
full_data_cleaned = full_data_cleaned.dropna()

# %%
full_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7024 entries, 0 to 9356
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           7024 non-null   object
#  1   Time           7024 non-null   object
#  2   CO(GT)         7024 non-null   object
#  3   PT08.S1(CO)    7024 non-null   object
#  4   C6H6(GT)       7024 non-null   object
#  5   PT08.S2(NMHC)  7024 non-null   object
#  6   NOx(GT)        7024 non-null   object
#  7   PT08.S3(NOx)   7024 non-null   object
#  8   NO2(GT)        7024 non-null   object
#  9   PT08.S4(NO2)   7024 non-null   object
#  10  PT08.S5(O3)    7024 non-null   object
#  11  T              7024 non-null   object
#  12  RH             7024 non-null   object
#  13  AH             7024 non-null   object
# dtypes: object(14)
# memory usage: 823.1+ KB

# %%
profile = ProfileReport(
    full_data_cleaned,
    title = "Simple Linear Regression - Precleaning Report",
    html  = {'style': {'full_width': True}},
    sort  = None)
profile.to_file(output_file='Postcleaning.html')
# Out:
# /home/javier/Documentos/data-mining/.venv/lib/python3.12/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# 100%|██████████| 14/14 [00:00<00:00, 14.84it/s]1<00:00, 13.76it/s, Describe variable: AH]
# Summarize dataset: 100%|██████████| 72/72 [00:09<00:00,  7.39it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:08<00:00,  8.63s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 48.30it/s]

# %%
full_data_cleaned = full_data_cleaned.drop(columns=['Date', 'Time'])

# %%
full_data_cleaned = full_data_cleaned.replace(",", ".", regex=True).astype(float)
# Out:
# /tmp/ipykernel_5884/1051142080.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   full_data_cleaned = full_data_cleaned.replace(",", ".", regex=True).astype(float)

# %%
objetive_column = 'C6H6(GT)'
y = full_data_cleaned.drop(columns=[objetive_column])
x = full_data_cleaned[objetive_column]

n = len(x)
y_len = y.shape[1]
k = 1

# %%
x_mean = np.mean(x)
y_mean = y.mean().to_numpy()

# %%
print(x_mean)
print(y_mean)
# Out:
# 10.464194191343964
# [-2.06648633e-01  1.11766444e+03  9.54511390e+02  2.49230780e+02
#   8.19890518e+02  1.13571327e+02  1.44658343e+03  1.05333044e+03
#   1.76254413e+01  4.89792284e+01  9.80810720e-01]

# %%
print("x")
print(x)
print("y")
print(y)
print("x_mean")
print(x_mean)
print("y_mean")
print(y_mean)
# Out:
# x
# 0       11.9
# 1        9.4
# 2        9.0
# 3        9.2
# 4        6.5
#         ...
# 9352    13.5
# 9353    11.4
# 9354    12.4
# 9355     9.5
# 9356    11.9
# Name: C6H6(GT), Length: 7024, dtype: float64
# y
#       CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0        2.6       1360.0         1046.0    166.0        1056.0    113.0
# 1        2.0       1292.0          955.0    103.0        1174.0     92.0
# 2        2.2       1402.0          939.0    131.0        1140.0    114.0
# 3        2.2       1376.0          948.0    172.0        1092.0    122.0
# 4        1.6       1272.0          836.0    131.0        1205.0    116.0
# ...      ...          ...            ...      ...           ...      ...
# 9352     3.1       1314.0         1101.0    472.0         539.0    190.0
# 9353     2.4       1163.0         1027.0    353.0         604.0    179.0
# 9354     2.4       1142.0         1063.0    293.0         603.0    175.0
# 9355     2.1       1003.0          961.0    235.0         702.0    156.0
# 9356     2.2       1071.0         1047.0    265.0         654.0    168.0
#
#       PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0           1692.0       1268.0  13.6  48.9  0.7578
# 1           1559.0        972.0  13.3  47.7  0.7255
# 2           1555.0       1074.0  11.9  54.0  0.7502
# 3           1584.0       1203.0  11.0  60.0  0.7867
# 4           1490.0       1110.0  11.2  59.6  0.7888
# ...            ...          ...   ...   ...     ...
# 9352        1374.0       1729.0  21.9  29.3  0.7568
# 9353        1264.0       1269.0  24.3  23.7  0.7119
# 9354        1241.0       1092.0  26.9  18.3  0.6406
# 9355        1041.0        770.0  28.3  13.5  0.5139
# 9356        1129.0        816.0  28.5  13.1  0.5028
#
# [7024 rows x 11 columns]
# x_mean
# 10.464194191343964
# y_mean
# [-2.06648633e-01  1.11766444e+03  9.54511390e+02  2.49230780e+02
#   8.19890518e+02  1.13571327e+02  1.44658343e+03  1.05333044e+03
#   1.76254413e+01  4.89792284e+01  9.80810720e-01]

# %%
x_mean
# Out:
# np.float64(10.464194191343964)

# %%
coeffients_tot = []

for i in range(y_len):
    y_i = y.iloc[:, i]
    y_i_mean = y_mean[i]
    
    coeffients = [0.0 for _ in range(k+1)]
    
    numerator = np.sum((x - x_mean) * (y_i - y_i_mean))
    denominator = np.sum((x - x_mean)**2)
    
    coeffients[1] = numerator / denominator      # b1
    coeffients[0] = y_i_mean - coeffients[1] * x_mean  # b0
    
    coeffients_tot.append(coeffients)

# %%
for i, coefs in enumerate(coeffients_tot):
    print(f"Variable {i}:\n\t b0 = {coefs[0]}\n\t b1 = {coefs[1]}")
# Out:
# Variable 0:
# 	 b0 = -5.441803397328531
# 	 b1 = 0.5002922029487636
# Variable 1:
# 	 b0 = 848.5118184440655
# 	 b1 = 25.721294239479768
# Variable 2:
# 	 b0 = 589.1522928109664
# 	 b1 = 34.915167860025065
# Variable 3:
# 	 b0 = 39.51251926594429
# 	 b1 = 20.041510801640904
# Variable 4:
# 	 b0 = 1078.1951088125884
# 	 b1 = -24.684613632555163
# Variable 5:
# 	 b0 = 73.30474524593835
# 	 b1 = 3.8480346309552864
# Variable 6:
# 	 b0 = 1065.3450017406537
# 	 b1 = 36.432659747534345
# Variable 7:
# 	 b0 = 561.4528139212752
# 	 b1 = 47.00578138947304
# Variable 8:
# 	 b0 = 15.126479504079157
# 	 b1 = 0.23881072868005004
# Variable 9:
# 	 b0 = 49.64322044999336
# 	 b1 = -0.06345372399852188
# Variable 10:
# 	 b0 = 0.8702984227822446
# 	 b1 = 0.010560994528982981

# %%
o_2 = []

for i, coefs in enumerate(coeffients_tot):
    b0 = coefs[0]
    b1 = coefs[1]

    y_i = y.iloc[:, i]    # columna i de y
    y_pred = b0 + b1 * x  # predicción para esa variable

    residuals = y_i - y_pred
    RSS = np.sum(residuals**2)

    print(f"Variable {i}: RSS = {RSS}")

    o_2.append(RSS / (n - 2))   # n - k - 1 = n - 2 en regresión simple
# Out:
# Variable 0: RSS = 3269041.74937351
# Variable 1: RSS = 76875507.80544609
# Variable 2: RSS = 17468155.44018617
# Variable 3: RSS = 146411569.58974612
# Variable 4: RSS = 213910907.97113493
# Variable 5: RSS = 10067647.581135135
# Variable 6: RSS = 369124217.53116035
# Variable 7: RSS = 300265878.6204801
# Variable 8: RSS = 531737.909485974
# Variable 9: RSS = 2127621.7787072067
# Variable 10: RSS = 1089.7770121574317

# %%
print(o_2)
# Out:
# [np.float64(465.54282958893623), np.float64(10947.808004193404), np.float64(2487.6325035867517), np.float64(20850.4086570416), np.float64(30462.9604060289), np.float64(1433.729362166781), np.float64(52566.821066812925), np.float64(42760.73463692397), np.float64(75.72456700170521), np.float64(302.9937024647119), np.float64(0.15519467561341949)]

# %%
X_matrix = np.vstack([np.ones(len(x)), x]).T

print(X_matrix)
# Out:
# [[ 1.  11.9]
#  [ 1.   9.4]
#  [ 1.   9. ]
#  ...
#  [ 1.  12.4]
#  [ 1.   9.5]
#  [ 1.  11.9]]

# %%
XT_X = np.dot(X_matrix.T, X_matrix)

print(XT_X)
# Out:
# [[   7024.     73500.5 ]
#  [  73500.5  1161198.43]]

# %%
XT_X_inv = np.linalg.inv(XT_X)

print(XT_X_inv)
# Out:
# [[ 4.21650742e-04 -2.66892717e-05]
#  [-2.66892717e-05  2.55053291e-06]]

# %%
cov_matrix = []
for element in o_2:
    var_cov_matrix = element * XT_X_inv
    cov_matrix.append(var_cov_matrix)

# %%
cov_matrix
# Out:
# [array([[ 0.19629648, -0.012425  ],
#         [-0.012425  ,  0.00118738]]),
#  array([[ 4.61615137, -0.29218902],
#         [-0.29218902,  0.02792274]]),
#  array([[ 1.04891209, -0.0663931 ],
#         [-0.0663931 ,  0.00634479]]),
#  array([[ 8.79159029, -0.55648222],
#         [-0.55648222,  0.05317965]]),
#  array([[12.84472987, -0.81303423],
#         [-0.81303423,  0.07769678]]),
#  array([[ 0.60453305, -0.03826519],
#         [-0.03826519,  0.00365677]]),
#  array([[22.16483912, -1.40297017],
#         [-1.40297017,  0.13407341]]),
#  array([[18.0300955 , -1.14125286],
#         [-1.14125286,  0.10906266]]),
#  array([[ 0.03192932, -0.00202103],
#         [-0.00202103,  0.00019314]]),
#  array([[ 0.12775752, -0.00808668],
#         [-0.00808668,  0.0007728 ]]),
#  array([[ 6.54379502e-05, -4.14203286e-06],
#         [-4.14203286e-06,  3.95829128e-07]])]

# %%
SEs = []
for cov_matrixs in cov_matrix:
    Se = []
    for coeffienct in range(k + 1):
        Se.append(np.sqrt(cov_matrixs[coeffienct, coeffienct]))
    SEs.append(Se)

# %%
SEs
# Out:
# [[np.float64(0.44305358553773716), np.float64(0.03445841419860733)],
#  [np.float64(2.148523067428578), np.float64(0.16710100129956032)],
#  [np.float64(1.024164094102795), np.float64(0.0796541811508027)],
#  [np.float64(2.9650615991944367), np.float64(0.23060714108750732)],
#  [np.float64(3.583954501267099), np.float64(0.27874142700760507)],
#  [np.float64(0.7775172343953239), np.float64(0.06047126529138025)],
#  [np.float64(4.707954876796992), np.float64(0.36616035727625607)],
#  [np.float64(4.246185994508819), np.float64(0.33024636418532666)],
#  [np.float64(0.17868777206306777), np.float64(0.013897409846040116)],
#  [np.float64(0.35743183902593234), np.float64(0.027799198017948227)],
#  [np.float64(0.008089372668496297), np.float64(0.0006291495275444433)]]
